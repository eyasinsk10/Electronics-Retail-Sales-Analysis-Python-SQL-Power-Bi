# %%
# !pip install pandas numpy openpyxl sqlalchemy pymysql
# Out:
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
#    -------------------------- ------------- 2/3 [openpyxl]
# ...

# %%
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\esk06\Downloads\archive\Electronic_sales_Sep2023-Sep2024.csv"

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        20000 non-null  int64
#  1   Age                20000 non-null  int64
#  2   Gender             19999 non-null  str
#  3   Loyalty Member     20000 non-null  str
#  4   Product Type       20000 non-null  str
#  5   SKU                20000 non-null  str
#  6   Rating             20000 non-null  int64
#  7   Order Status       20000 non-null  str
#  8   Payment Method     20000 non-null  str
#  9   Total Price        20000 non-null  float64
#  10  Unit Price         20000 non-null  float64
#  11  Quantity           20000 non-null  int64
#  12  Purchase Date      20000 non-null  str
#  13  Shipping Type      20000 non-null  str
#  14  Add-ons Purchased  15132 non-null  str
#  15  Add-on Total       20000 non-null  float64
# dtypes: float64(3), int64(4), str(9)
# ...

# %%
df.shape
# Out:
# (20000, 16)

# %%
df.isnull().sum()
# Out:
# Customer ID             0
# Age                     0
# Gender                  1
# Loyalty Member          0
# Product Type            0
# SKU                     0
# Rating                  0
# Order Status            0
# Payment Method          0
# Total Price             0
# Unit Price              0
# Quantity                0
# Purchase Date           0
# Shipping Type           0
# Add-ons Purchased    4868
# Add-on Total            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Customer ID            int64
# Age                    int64
# Gender                   str
# Loyalty Member           str
# Product Type             str
# SKU                      str
# Rating                 int64
# Order Status             str
# Payment Method           str
# Total Price          float64
# Unit Price           float64
# Quantity               int64
# Purchase Date            str
# Shipping Type            str
# Add-ons Purchased        str
# Add-on Total         float64
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['Customer ID',
#  'Age',
#  'Gender',
#  'Loyalty Member',
#  'Product Type',
#  'SKU',
#  'Rating',
#  'Order Status',
#  'Payment Method',
#  'Total Price',
#  'Unit Price',
#  'Quantity',
#  'Purchase Date',
#  'Shipping Type',
#  'Add-ons Purchased',
#  'Add-on Total']

# %%
df= df.drop_duplicates()

# %%
df.replace(['#N/A',''],np.nan,inplace=True)
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 0             1000   53    Male             No   Smartphone  SKU1004       2
# 1             1000   53    Male             No       Tablet  SKU1002       3
# 2             1002   41    Male             No       Laptop  SKU1005       3
# 3             1002   41    Male            Yes   Smartphone  SKU1004       2
# 4             1003   75    Male            Yes   Smartphone  SKU1001       5
# ...            ...  ...     ...            ...          ...      ...     ...
# 19995        19996   27  Female             No   Smartphone   SMP234       4
# 19996        19996   27  Female            Yes       Laptop   LTP123       4
# 19997        19996   27  Female             No   Headphones   HDP456       4
# 19998        19997   27    Male             No   Headphones   HDP456       1
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...

# %%
df= df.loc[:, df.isnull().mean() <0.5]

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df =df.apply(lambda x: x.str.strip() if x.dtype =='object' else x)

# %%
df['Age'].fillna(df['Age'].median(), inplace = True)
# Out:
# C:\Users\esk06\AppData\Local\Temp\ipykernel_12860\3612560828.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(df['Age'].median(), inplace = True)
# 0        53
# 1        53
# 2        41
# 3        41
# 4        75
#          ..
# 19995    27
# 19996    27
# 19997    27
# 19998    27
# 19999    27
# ...

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'],errors = 'coerce')

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                          str
# Loyalty Member                  str
# Product Type                    str
# SKU                             str
# Rating                        int64
# Order Status                    str
# Payment Method                  str
# Total Price                 float64
# Unit Price                  float64
# Quantity                      int64
# Purchase Date        datetime64[us]
# Shipping Type                   str
# Add-ons Purchased               str
# Add-on Total                float64
# dtype: object

# %%
cols = ['Age','Rating','Total Price','Unit Price','Quantity','Add-on Total']

for c in cols:
    df[c]=pd.to_numeric(df[c],errors = 'coerce')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total
# ...

# %%
df  = df[df['Quantity']> 0]

# %%
df['Sales Revenue'] = df['Total Price'] + df['Add-on Total']

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  Unit Price  Quantity  \
# 0    Cancelled    Credit Card      5538.33      791.19         7
# 1    Completed         Paypal       741.09      247.03         3
# 2    Completed    Credit Card      1855.84      463.96         4
# 3    Completed           Cash      3164.76      791.19         4
# 4    Completed           Cash        41.50       20.75         2
#
#   Purchase Date Shipping Type              Add-ons Purchased  Add-on Total  \
# ...

# %%
df['Order ID'] = range(1,len(df)+1)

# %%
df['Year'] = df['Purchase Date'].dt.year

# %%
df['Day'] = df['Purchase Date'].dt.day_name()

# %%
df['Month'] = df['Purchase Date'].dt.month_name()

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  ...  Quantity  Purchase Date  \
# 0    Cancelled    Credit Card      5538.33  ...         7     2024-03-20
# 1    Completed         Paypal       741.09  ...         3     2024-04-20
# 2    Completed    Credit Card      1855.84  ...         4     2023-10-17
# 3    Completed           Cash      3164.76  ...         4     2024-08-09
# 4    Completed           Cash        41.50  ...         2     2024-05-21
#
#   Shipping Type              Add-ons Purchased Add-on Total  Sales Revenue  \
# ...

# %%
bins = [17,35,55,75,np.inf]
labels = ['18-35','36-55','56-75','75+']

df['Age-Group'] = pd.cut(df['Age'],bins=bins,labels=labels)

# %%
df.head()
# Out:
#    Customer ID  Age Gender Loyalty Member Product Type      SKU  Rating  \
# 0         1000   53   Male             No   Smartphone  SKU1004       2
# 1         1000   53   Male             No       Tablet  SKU1002       3
# 2         1002   41   Male             No       Laptop  SKU1005       3
# 3         1002   41   Male            Yes   Smartphone  SKU1004       2
# 4         1003   75   Male            Yes   Smartphone  SKU1001       5
#
#   Order Status Payment Method  Total Price  ...  Purchase Date  Shipping Type  \
# 0    Cancelled    Credit Card      5538.33  ...     2024-03-20       Standard
# 1    Completed         Paypal       741.09  ...     2024-04-20      Overnight
# 2    Completed    Credit Card      1855.84  ...     2023-10-17        Express
# 3    Completed           Cash      3164.76  ...     2024-08-09      Overnight
# 4    Completed           Cash        41.50  ...     2024-05-21        Express
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        20000 non-null  int64
#  1   Age                20000 non-null  int64
#  2   Gender             20000 non-null  str
#  3   Loyalty Member     20000 non-null  str
#  4   Product Type       20000 non-null  str
#  5   SKU                20000 non-null  str
#  6   Rating             20000 non-null  int64
#  7   Order Status       20000 non-null  str
#  8   Payment Method     20000 non-null  str
#  9   Total Price        20000 non-null  float64
#  10  Unit Price         20000 non-null  float64
#  11  Quantity           20000 non-null  int64
#  12  Purchase Date      20000 non-null  datetime64[us]
#  13  Shipping Type      20000 non-null  str
#  14  Add-ons Purchased  15132 non-null  str
#  15  Add-on Total       20000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID             0
# Age                     0
# Gender                  0
# Loyalty Member          0
# Product Type            0
# SKU                     0
# Rating                  0
# Order Status            0
# Payment Method          0
# Total Price             0
# Unit Price              0
# Quantity                0
# Purchase Date           0
# Shipping Type           0
# Add-ons Purchased    4868
# Add-on Total            0
# Sales Revenue           0
# Order ID                0
# Year                    0
# Day                     0
# Month                   0
# Age-Group               0
# dtype: int64

# %%
df.to_csv(r'C:\Users\esk06\Downloads\archive\electronic_Sales_data.csv',index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:jhilik%04111@localhost/electronics')

# %%
df.to_sql(
    name = 'order',
    con = engine,
    if_exists = 'replace',
    index = False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.to_sql(
#       2     name = 'order',
#       3     con = engine,
#       4     if_exists = 'replace',
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

# %%
file_path = r"C:\\Users\\esk06\\Downloads\\archive\\electronic_Sales_data.csv"

# %%
df = pd.read_csv(file_path)

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:jhilika%40111@localhost/electronics')

# %%
from urllib.parse import quote_plus
from sqlalchemy import create_engine

password = quote_plus("jhilik@111")
engine = create_engine(f"mysql+pymysql://root:{password}@localhost/electronics")

# %%
df.to_sql(
    name = 'orders',
    con = engine,
    if_exists = 'replace',
    index = False
)
# Out:
# 20000
